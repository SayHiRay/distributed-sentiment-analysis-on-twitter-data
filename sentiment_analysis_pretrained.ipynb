# %%
import pandas as pd
import numpy as np
import csv
from datetime import datetime
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
vader_analyzer = SentimentIntensityAnalyzer()

# %%
with open(r'./twitter_scraper/twitter_data.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        [date_str, text, user_id, location] = row
        dt = datetime.strptime(date_str, "%a %b %d %H:%M:%S %z %Y")
        print(text)
        print(vader_analyzer.polarity_scores(text))
# Out:
# After today I am not spending a single fucking dime. Yeah I’ll starve, and yeah I’ll miss my chances on getting shit I want, but enough is enough Jasmine. :sleepy_face:
# {'neg': 0.177, 'neu': 0.636, 'pos': 0.187, 'compound': -0.1682}
# Trust the process
# {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'compound': 0.5106}
# USER_NAME Seton Hall, St. John, Syracuse and UConn didn't make it.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# *21 but facts URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME :eyes::thinking_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Happy Birthday baby love you URL
# {'neg': 0.0, 'neu': 0.336, 'pos': 0.664, 'compound': 0.836}
# USER_NAME 8 assist
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I just love their smiles :smiling_face_with_heart-eyes: URL
# {'neg': 0.0, 'neu': 0.354, 'pos': 0.646, 'compound': 0.8074}
# Me since my fantasy draft last night URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Watching USER_NAME with my my 70something mom when she says, “Is that guy (James) the bone-carrier for this show?? :rolling_on_the_floor_laughing: USER_NAME  #nevertooold
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# True :drooling_face::smirking_face: @ Humber College URL
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.4215}
# Cam Da Man :smiling_face_with_heart-eyes: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Dude you’re a better rapper than he is I put that lol
# {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.6908}
# USER_NAME You sir, need to go back to your desert on a horse with no name! Asshat!
# {'neg': 0.157, 'neu': 0.843, 'pos': 0.0, 'compound': -0.4184}
# :loudly_crying_face: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Causeee we gone tooot tooot URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Getting a roku is probably one of the better life decisions I’ve made
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# ben platt has the voice of a god, the raw emotional presence of some primal beast, and the face of an infant
# {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'compound': 0.4019}
# USER_NAME Agree, totally!! You’ll make the best decision for you!!  If it makes you feel any better, I have plenty of married friends that I still call by their maiden name (even though their names have changed).  Lol it’s such a tough decision and kinda sad to lose part of your identity!!
# {'neg': 0.105, 'neu': 0.637, 'pos': 0.259, 'compound': 0.8984}
# #AMERICA making stupid people famous through tragedy #MarchForOurLives
# {'neg': 0.565, 'neu': 0.435, 'pos': 0.0, 'compound': -0.8316}
# If I could come back as someone, it’d be George Straight no question.
# {'neg': 0.156, 'neu': 0.709, 'pos': 0.135, 'compound': -0.0772}
# USER_NAME Gurl if you bring him down & out of that office, I will personally donate to any GoFundMe you might setup :victory_hand::medium-light_skin_tone:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This is the reason I don’t talk to anyone because they always like to bend the truth and I end up looking childish.
# {'neg': 0.088, 'neu': 0.72, 'pos': 0.192, 'compound': 0.3818}
# Can I retweet this more than once? URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Those curls :smiling_face_with_heart-eyes::smiling_face_with_heart-eyes: #idolOn2 URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Segunda maldita vez en el día que salgo corriendo detrás de un elotero y no lo alcanzo gracias.:ear_of_corn::broken_heart:
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.296}
# USER_NAME USER_NAME In the back of her mind she keeps hearing Omar Omar Omar Omar
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Need some consistency in your game? I’m now fitting for USER_NAME Single Length clubs at my… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Good luck!
# {'neg': 0.0, 'neu': 0.139, 'pos': 0.861, 'compound': 0.7345}
# USER_NAME Getting better I’m sure I would work you though :smiling_face_with_horns:
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.6369}
# I need to keep in mind that other people’s phones actually make noise when I text them so I probably should stop sending them 10+ messages in a row :face_with_tears_of_joy: I forget because my phone has been on silent since anout... 2013
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.5209}
# Dile que yo estoy muy bien, que nunca he estado mejor.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Interested in a #job in #Homer, AK? This could be a great fit: URL #Legal #Hiring #CareerArc
# {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.8519}
# “Sunset Zen” for Lisa. lisadenback Call or click to schedule your new spring look.… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It's 8:30 p.m. and my phone says 80 degrees in Dallas :cowboy_hat_face::person_raising_hand::medium-light_skin_tone::see-no-evil_monkey::speak-no-evil_monkey:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# saxon.official in #Ottawa. On assignment for USER_NAME
# .
# .
# .
# #concertphotography #saxon… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Loving our USER_NAME Reader Dinner with pelipelikitchen! Casual, big, flavorful portions… URL
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.7177}
# bro I’m short of words lmaoooo URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I miss Joseline  :weary_face: id rather see her and the baby rather than those kids here!
# {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.2244}
# USER_NAME URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME  URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME I’m not impressed by the dunkies shoes. Why did they go with brand colors. They should look like donuts!!!
# {'neg': 0.143, 'neu': 0.752, 'pos': 0.104, 'compound': -0.2335}
# USER_NAME Literally sameeee having my hair played with will put me to sleep instantly :face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.34}
# #FlaPanthers will be 1 pt back of #NJDevils with a game in hand. Devils host Canes tomorrow who played tonight.
# {'neg': 0.152, 'neu': 0.617, 'pos': 0.23, 'compound': 0.2263}
# Jesus! USER_NAME vs. USER_NAME needs to happen at #WrestleMania34! Book it! USER_NAME #RAW
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME Challenge accepted :smiling_face_with_sunglasses:
# {'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.34}
# My money stackin now, not my problems :sleeping_face:
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.3089}
# Por segunda noche consecutiva  veré " a él no le gustas tanto"
# {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}
# USER_NAME Liz remind me to give you a copy
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This ain't a yes, this ain't a no.
# {'neg': 0.277, 'neu': 0.491, 'pos': 0.232, 'compound': -0.0951}
# .USER_NAME USER_NAME & USER_NAME all are up for the XXL 2018 Freshmen class. I love to see that shit for the city, that’s very good look! Hopefully we get more on the cover than off.
# {'neg': 0.083, 'neu': 0.671, 'pos': 0.246, 'compound': 0.7934}
# Like 2 years ago I told my friend (a female) not to take it personally but her eyebrows were shaped like sperm cells. She recently texted me and started thanking me for being honest and changing her life:face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.8898}
# tomorrow’s my mfffff birthdayyy;)))
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Si no fuéramos revolucionarios y comunistas de verdad, ¿cree usted que el gobierno de EEUU se molestaría en intentar destruir la Revolución Cubana?
# {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.296}
# USER_NAME Nice try. What’d you get chump?
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
# USER_NAME Mais je comprend ton interrogation!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# So I’ve got this giant thing of Powerade #powerade going to be peeing all night probably… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# En un país donde funciona la justicia, hay medidas para sustentar el proceso aquí solo cuentos. USER_NAME USER_NAME USER_NAME #CorruptosVIP #JusticiaDeJuguete #DictaduraDeLaImpunidad #YoNoLoSabía URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# COPPPPPPPP URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Loved it
# {'neg': 0.0, 'neu': 0.204, 'pos': 0.796, 'compound': 0.5994}
# Damn Safaree on every #vh1 show.....LITERALLY........ #LeaveitToStevie
# {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.4019}
# USER_NAME people who clap for the landing #raiseyourstandards
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME is such a fine human being :smiling_face_with_heart-eyes::smirking_face: URL
# {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.2023}
# USER_NAME Terrible!
# {'neg': 0.772, 'neu': 0.228, 'pos': 0.0, 'compound': -0.5255}
# USER_NAME The Spartan walls are crumbling.... URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :direct_hit: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# That’s right. 2. 2015-2016, 2016-2018. Bitch, I’m tied.
# {'neg': 0.352, 'neu': 0.648, 'pos': 0.0, 'compound': -0.5859}
# If Iman wasn’t a basketball player he look like the type of nigga that always ask to borrow $40 #TeyanaAndIman URL
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.3612}
# USER_NAME USER_NAME USER_NAME I am not ashamed to admit it...
# I am ashamed of his and the .USER_NAME s fall from journalistic integrity.
# THESE ARE ALL RATINGS/$$$ WHORES!
# {'neg': 0.184, 'neu': 0.583, 'pos': 0.233, 'compound': 0.1717}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME Why don't you do a little research and find out who this dude Torshin is, hm? Then you'd actually know what you were talking about.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# junie just gave me baby fever she’s so precious :loudly_crying_face::loudly_crying_face:
# {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'compound': 0.6948}
# USER_NAME *abbys girlfriend
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Everything means nothing if i don’t have you :blue_heart::blue_heart::blue_heart:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# But I’m not high maintenance so that’s just me. I’m very simple and appreciate the little things.
# {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.4522}
# USER_NAME Except in the case of the Viet Cong.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME The Two Mrs. Cranes
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I need a shower after that game.... #Sixers
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I want to dress like a freaking modern wizard or something idk
# {'neg': 0.3, 'neu': 0.429, 'pos': 0.271, 'compound': -0.1027}
# Mood URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #internationalspacestation #ISS #sonyalpha #sonya6000 #nofilter lil crop. @ Grimsby, Ontario URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# URL More than 1 Million People Watched a Fortnite Stream on YouTube Last Night - IGN News URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Yz215 psquadLafamilia URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# All I can think about is stuffing my face with grilled oysters! :drooling_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# be faking gay and shit :expressionless_face:
# {'neg': 0.615, 'neu': 0.385, 'pos': 0.0, 'compound': -0.7506}
# USER_NAME USER_NAME Yawn
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# And we'll always be together, right? URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Is everyone in my family pregnant right now!!! Sheeesh
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME why?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Shots fired USER_NAME URL
# {'neg': 0.545, 'neu': 0.455, 'pos': 0.0, 'compound': -0.5574}
# USER_NAME Perfect response
# {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.5719}
# #foreveralone URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME He wasn’t favored against Pitt or Kansas
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}
# Fultz is a future HOF lock don’t @ me
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I need to master French, because I’m moving back to France after graduation.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Well shit now I have options and I don’t know what to do
# {'neg': 0.245, 'neu': 0.612, 'pos': 0.143, 'compound': -0.3612}
# Child support!?USER_NAME
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Whenever I put my slippers on my dog gets so excited because she thinks it means we’re going outside and then I’m just like nope that is the opposite of what this means
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.6825}
# “Every app is Tinder if you try hard enough.”
#
# — Schlager, date Unknown.
# {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.1027}
# URL Limbo, Inside Dev Playdead Possibly Teases Next Game URL
# {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}
# USER_NAME Agh that’s bs as soon as I get it I’m canceling that insurance it’s worthless lol
# {'neg': 0.147, 'neu': 0.711, 'pos': 0.142, 'compound': -0.0258}
# we need a disney princess who speaks in stan twitter vernacular
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Poutine. Lol. #iZOMBiE
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# USER_NAME  URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I’m sorry to tell you but ummmmm that’s not a toothbrush USER_NAME USER_NAME URL
# {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.0387}
# Concerts in Dallas on Fri? Lmk :black_heart:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Nah man you can’t cheat on didi like that...Stanton’s all mine back off
# {'neg': 0.246, 'neu': 0.615, 'pos': 0.14, 'compound': -0.2263}
# Shut up !!!!!!:face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME Haha I’ve learned that from all the online comments back! Getting schooled on some G train history today ;)
# {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.636}
# Pretty please ... :raising_hands::raising_hands::raising_hands::raising_hands::raising_hands: URL
# {'neg': 0.0, 'neu': 0.353, 'pos': 0.647, 'compound': 0.6705}
# #happybirthday #daddyslittlegirl #family @ Chuck E. Cheese’s URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Its Monday again and this one of the most highlighted nights of the week!! .
# USER_NAME x… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bot URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# PLS CAN ANYONE HELP MY FRIEND IS DESPERATE URL
# {'neg': 0.159, 'neu': 0.345, 'pos': 0.497, 'compound': 0.5994}
# Brb starting a grease fire
# {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.34}
# Lucia di Lammermoor by Maria Callas -Donizetti #KickOutTheJams URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Gorgeous!! :face_blowing_a_kiss: URL
# {'neg': 0.0, 'neu': 0.396, 'pos': 0.604, 'compound': 0.6792}
# SUSPICIOUS SUBJ, VEH, OR CIRCUMSTANCE at 500 BLOCK OF SE 112TH AVE, PORTLAND, OR [Portland Police #PP18000099913] 18:20 #pdx911
# {'neg': 0.288, 'neu': 0.712, 'pos': 0.0, 'compound': -0.7824}
# There’s POWER in your PURPOSE!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It seems as if I just fall apart when Ashleigh’s not around
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Y’all bitches need to listen fr URL
# {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.5994}
# I realized (after the fact) that I talked to both the CEO and HR person at my second job today in regards to when I’m quitting...while wearing pajamas. Because it was pajama day at the school job today.
#
# Good thing I’m quitting in a month  bc they defs think I’m a weirdo now..
# {'neg': 0.053, 'neu': 0.892, 'pos': 0.055, 'compound': 0.0258}
# USER_NAME Yo yo yo Yorick!
# We was homies.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# THEFT - COLD at 7000 BLOCK OF N DENVER AVE, PORTLAND, OR [Portland Police #PP18000099887] 17:27 #pdx911
# {'neg': 0.206, 'neu': 0.794, 'pos': 0.0, 'compound': -0.5622}
# USER_NAME Stop using "affair" . By her own admission they had unprotected sex (yuck) only once. That's a one night stand . Wham Bam thank you mam!
# {'neg': 0.175, 'neu': 0.737, 'pos': 0.088, 'compound': -0.3595}
# USER_NAME USER_NAME USER_NAME Oh my gosh!!! How COOL!! :blue_heart:
# {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6371}
# So my honey is giving grilled octopus samples to a person she just met at the bar. #ILoveHer
# {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.34}
# UConn really will never lose URL
# {'neg': 0.0, 'neu': 0.665, 'pos': 0.335, 'compound': 0.3657}
# Yep URL
# {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.296}
# THIS WORLD DOESN’T DESERVE YOU URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I’m sitting here trying to figure out why can I relate to them so much, but especially her attitude:fire: that’s me all the way:face_with_tears_of_joy:...I just realized we’re both #Sagittarius :alien::alien:USER_NAME
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# anddddd that is what breaks my heart still to this day.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# We'll stated. URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME  URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Redd dropped 50 once. On Kobe too I think
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Need i say more:face_with_tears_of_joy::face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tom is Bartending tonight and if you love trivia he's all about it! Come in with your best and if you stump him your 1st beers on us! #Cheers #MondayTrivia #LateNightHappyHour #Houston #Htown URL
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.8745}
# USER_NAME USER_NAME I've seen an play way worse and win. They deserved better but......hockey:person_shrugging:
# {'neg': 0.14, 'neu': 0.45, 'pos': 0.41, 'compound': 0.7184}
# Moist ...yet on #MANdingoMonday? :eggplant: #freeBaLLer #freeBALLing #GoComMANdo #MadeYaLook #bulge #BlackSnake :shower: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Oooooooo how long did u keep it?
#
# Yaaaas bayley, dont hold back
# #RAW #wweuniverse
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Winter stole summer's thrill
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}
# USER_NAME USER_NAME Damn guise :confused_face:
# {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019}
# Stay wokeeeee :eye:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# When Eminem said “you only got one shot  do not miss your change to blow” I felt that:loudly_crying_face::hundred_points:
# {'neg': 0.0, 'neu': 0.917, 'pos': 0.083, 'compound': 0.1139}
# I love how brave and wise Sara USER_NAME  is she is so bad ass :open_hands::smiling_face_with_open_mouth_&_cold_sweat::red_heart::red_heart::red_heart::hundred_points::hundred_points::hundred_points: #LegendsOfTomorrow
# {'neg': 0.0, 'neu': 0.389, 'pos': 0.611, 'compound': 0.9403}
# The day I propose to the love of my life ima cry like shit :loudly_crying_face::loudly_crying_face::loudly_crying_face:
# {'neg': 0.286, 'neu': 0.427, 'pos': 0.286, 'compound': 0.0}
# When I was younger, my daddy: “you need to start making better choices. Woopty woop woop woop...”
# Me riding on the way to church: URL
# {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.4404}
# Is the Easter bunny a? (everyone was giving me different answers today)
# {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.34}
# It’s confirmed.. flying was not made for me lol URL
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}
# Please don't pop my tab
# {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.3182}
# USER_NAME says it best. Looking for forgiveness
# #WordsOfALostBoy URL
# {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.743}
# USER_NAME  &’ they say we the ones that’s terrible in relationships :thinking_face: URL
# {'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.4767}
# Consider where the money $$$$ came from to get them all to Washington and their capital buildings, you don’t travel that far on milk money saved URL
# {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.4215}
# I hate my situation now.
# {'neg': 0.552, 'neu': 0.448, 'pos': 0.0, 'compound': -0.5719}
# Glad to see Fultz back on the floor USER_NAME
# {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.4588}
# USER_NAME USER_NAME USER_NAME This is my FAVORITE Suda game!
# {'neg': 0.0, 'neu': 0.665, 'pos': 0.335, 'compound': 0.6155}
# cause kemba walker was buggin URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME Thanks for the truth president Carter.
# {'neg': 0.0, 'neu': 0.574, 'pos': 0.426, 'compound': 0.6369}
# dont drink a redbull & 3 shots of espresso on an empty stomach kiddos ;-)
# {'neg': 0.13, 'neu': 0.725, 'pos': 0.145, 'compound': 0.0516}
# USER_NAME Mind your own bees wax
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# He’s so cute I wanna die URL
# {'neg': 0.363, 'neu': 0.349, 'pos': 0.287, 'compound': -0.2193}
# USER_NAME oh
#
# ok
#
# ill walk myself out
#
# ;c
# {'neg': 0.255, 'neu': 0.545, 'pos': 0.2, 'compound': -0.1531}
# Drivin us back in #familytime #teamgibbs #myyoungest3 @ Destin, Florida URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# So far I got into 10/15 schools that Ifot applied for.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Who remembers #Zynga? Those annoying game requests that kept filling up your Facebook… URL
# {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.4019}
# People do whatever they want and will never care
# {'neg': 0.24, 'neu': 0.641, 'pos': 0.119, 'compound': -0.3244}
# The amazing USER_NAME dropped in tonight by my surprise. Had the honor of watching her… URL
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.8442}
# Raw coming at you love backstage from a High School in Cleveland, OH! #RAW
# {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6696}
# AND STILL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Drinking a Russian Imperial Stout by USER_NAME @ Green Bus Brewing — URL #photo
# {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.1779}
# Bought myself a new cook book #treatyoself @ Anaheim, California URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sasha Banks and Bayley are brawling!! #Raw
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Strictly dickly URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME How is your Monday so far?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# There’s no better feeling than taking your socks off after work
# {'neg': 0.151, 'neu': 0.548, 'pos': 0.301, 'compound': 0.296}
# THIS IS AMAZING :smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::smiling_face_with_heart-eyes::smiling_face_with_heart-eyes: #Raw
# {'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.6739}
# BEAT EM DOWN!!!!!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #Unilateral #gymlife #health #fitness #fit #fitnessmodel #fitnessaddict #fitspo #workout… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME You are your own best representative, great job on 60 minutes
# {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'compound': 0.8519}
# USER_NAME USER_NAME Why - because of the illegal camping?
# {'neg': 0.34, 'neu': 0.66, 'pos': 0.0, 'compound': -0.5574}
# Post game interview with USER_NAME USER_NAME USER_NAME following a 7-1 loss to Lake Norman Charter is now USER_NAME Facebook page and URL
# {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.3182}
# While on a hike both kids had to pee. My son went behind some bushes and took care of business. I asked my daughter if she was gonna go and she said no bc she has to wipe not shake it :face_with_tears_of_joy:
# {'neg': 0.05, 'neu': 0.842, 'pos': 0.107, 'compound': 0.3649}
# Im so excited to go home tomorrow and see my princess!!:dog_face::heart_with_arrow:
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5068}
# THIS FIT IS FIRE URL
# {'neg': 0.304, 'neu': 0.38, 'pos': 0.316, 'compound': 0.0258}
# #prendele on bio:fire::clapper_board: please subscribe to my channel!:grinning_face_with_smiling_eyes:
# #newyorkchicanos #nyc #puebla #millonario… URL
# {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.3802}
# I knew I wasn’t the only one who felt this way about my significant other. #UAPB_RYS18 #Lane_RYS18 #UNCFSU_RYS18 URL
# {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'compound': 0.2023}
# USER_NAME  URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME happy birthday :party_popper::wrapped_gift:
# {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'compound': 0.5719}
# Cardi’s album drops the day before my birthday :nerd_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #OUTC18 USER_NAME will you make the sessions slides available?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Just give me some USER_NAME baseball man
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Yo my life is going great man!
# {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.6588}
# Copper In Vitamins Killing Us!  Secret Exposed! URL
# {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.7418}
# Why does power-glide go so hard
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.2183}
# Reynolds, King and Moree had big hits in the 5th in a 5-4 win @ ACS. J.Thomas with the win & King the save. USER_NAME, USER_NAME
# {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.8957}
# USER_NAME scammers alert! URL
# {'neg': 0.0, 'neu': 0.546, 'pos': 0.454, 'compound': 0.3595}
# Happy Born Day USER_NAME URL
# {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'compound': 0.5719}
# Fultz had 8 assists in just 14 minutes.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# My mom still to this day thinks USER_NAME is my most responsible friend URL
# {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.7245}
# Feel like i lost my bestfriend :confused_face:
# {'neg': 0.261, 'neu': 0.455, 'pos': 0.284, 'compound': 0.0516}
# Hosanna Palm Sunday -- source: YouTube.  AskAmyS wrote: "Video I created that uses the Travis Cottrell version of Holy, Holy, Holy and clips from Visual Bible's Jesus The Christ". URL URL
# {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.25}
# :selfie::medium-dark_skin_tone:#photoaday #vscogram #vsco #vscogood #photo #photography #clouds #cloudscape #skyline… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# this tweet did not age well URL
# {'neg': 0.232, 'neu': 0.768, 'pos': 0.0, 'compound': -0.2057}
# #dancer #beautiful #gorgeous #woman @ The Federal NoHo URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# hola hermanas
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #elevated #production #staytunedformore @ Adams Point, Oakland, California URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME The one*
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Appreciate that bro! Make it happen this year !!
# {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.5538}
# USER_NAME USER_NAME A mi me caias super y me parecias muy varonil, de los mas de el grupo de 16 con Cepeda
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.5994}
# 1216 Vyse Avenue, the Bronx URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Also just so I’m clear from here on out I’m #teamsasha all the way USER_NAME
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4364}
# Sin ti mi vida no está completa :face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss::face_blowing_a_kiss: USER_NAME USER_NAME
# {'neg': 0.42, 'neu': 0.58, 'pos': 0.0, 'compound': -0.7003}
# USER_NAME That Explains Alot...
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# fishing by my self this evening was definitely much needed.
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# USER_NAME That episode put my heart in a twist. Nothing is ever fair in love is it? #Timeless
# {'neg': 0.093, 'neu': 0.709, 'pos': 0.198, 'compound': 0.5003}
# USER_NAME USER_NAME You told me that the whole night was already planned.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME You led a crap load of laps and had a great run. Victory will soon be yours for sure!
# {'neg': 0.107, 'neu': 0.617, 'pos': 0.275, 'compound': 0.6239}
# I’m unavailable for the foolishness lmao URL
# {'neg': 0.239, 'neu': 0.427, 'pos': 0.333, 'compound': 0.2732}
# ur cancelled bro every song u drop sounds the same don’t even be dissing lil uzi rn URL
# {'neg': 0.215, 'neu': 0.785, 'pos': 0.0, 'compound': -0.4767}
# Do you ever think about stalking me cause i do in case you were wondering ..
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I want an arizona so bad rn.
# {'neg': 0.459, 'neu': 0.409, 'pos': 0.133, 'compound': -0.6359}
# USER_NAME Can't wait!!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME No no. I meant I can’t believe they left it that way.
# {'neg': 0.306, 'neu': 0.694, 'pos': 0.0, 'compound': -0.5267}
# You are me. I am you. URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME On god :face_with_tears_of_joy::face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.2732}
# I was raised in a Mexican household to. That has nothing to do with making it your responsibility. :unamused_face: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# WOOOOOOOW
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Same
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Then suddenly she’s not yo ho no mo... URL via USER_NAME
# {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.2235}
# Future Frat boy URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Leg sleeve outline by avelourdtattoos -In progress @ 27 Tattoo Studio URL
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}
# Southerners are: more attractive, more polite, and make better fried chicken:sun_with_face::flexed_biceps::medium-dark_skin_tone::poultry_leg: @ Jacksonville,… URL
# {'neg': 0.0, 'neu': 0.644, 'pos': 0.356, 'compound': 0.7264}
# Oh it's trish vs lita pre mania 18 remixed
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME once you’re in fuckin jail
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# o :whale:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Add me on xbox my gamertag is s9ecia7k
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I’m happy to read this announcement. I love reading Williamnson and I’m already an Atlantic subscriber. URL
# {'neg': 0.0, 'neu': 0.639, 'pos': 0.361, 'compound': 0.836}
# USER_NAME please follow me back, I have a few questions for you.
# {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
# USER_NAME I’m hot
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This gave me ode anxiety URL
# {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.1779}
# New things at USER_NAME: Michelob Ultra and a photo booth! Things that haven't changed: free… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Thank you haha! I like it a lot
# {'neg': 0.0, 'neu': 0.325, 'pos': 0.675, 'compound': 0.807}
# USER_NAME Ohhh :face_with_open_mouth: I would love too!!
# {'neg': 0.0, 'neu': 0.511, 'pos': 0.489, 'compound': 0.6988}
# If you aren’t helping me to be better, then get out of my way.
# {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.6249}
# Happy bday pretty gal!!! (*: USER_NAME
# {'neg': 0.0, 'neu': 0.34, 'pos': 0.66, 'compound': 0.8306}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME ‘Psychographic Microtarget’ I like it...
#
# like the saying goes: “If the product is free then *you* are the product.”  ;^}
# {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.8074}
# USER_NAME How’d it not go in!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME I too will take one apology letter
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.0516}
# USER_NAME :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Beibis, I’m home (@ Miss Jessie's Place in Mexico, Estado de mexico) URL
# {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.1531}
# Fantastic time today in Toronto with j66buk, Edith & Annie. The views from the top of this baby… URL
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.6597}
# USER_NAME USER_NAME You right:thinking_face: good thing she already wifed up:relieved_face::flexed_biceps::medium_skin_tone:
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
# USER_NAME USER_NAME Thanks, I’ll give that a shot! I had Untwitched but it stopped working :(
# {'neg': 0.334, 'neu': 0.566, 'pos': 0.1, 'compound': -0.6749}
# Odio esos días en que nadie "nos entiende" :angry_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Until someone pisses you off lol
# {'neg': 0.235, 'neu': 0.49, 'pos': 0.275, 'compound': 0.1027}
# USER_NAME tweet a USER_NAME movie quote and I'll buy a riot squad t shirt
# {'neg': 0.265, 'neu': 0.735, 'pos': 0.0, 'compound': -0.5574}
# Do something you've never done before. Do something you've always been scared to do. Do something that makes you uncomfortable. Do something because it's the perfect time to.
# {'neg': 0.161, 'neu': 0.731, 'pos': 0.108, 'compound': -0.2023}
# Lemon remix ft.drake is just :loudly_crying_face::black_heart:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Who got a box truck for sell ?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME #TrumpRussia and stupid people who bought your bullshit. #WeCallBS #NotMyPresident. It took another asshole 6 months more to write a book about what happened?
# {'neg': 0.247, 'neu': 0.753, 'pos': 0.0, 'compound': -0.802}
# Mentally in my bag :money_bag:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
#
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Oye si haha maybe el viernes me festejo en the city.
# {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.4588}
# USER_NAME Lol if he was sent from god for her then she would want him
# {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.6369}
# • "Una sola mirada me basta para matarme y mandarme al infierno..." :microphone::musical_notes:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# LOLLLLLLLL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Here goes that Sasha heel turn everyone wanted and I am just as indifferent now as I was when I first heard the rumor a whiiiile back.
# {'neg': 0.076, 'neu': 0.924, 'pos': 0.0, 'compound': -0.2023}
# Why you never call me :thinking_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME Yahtzee
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME I want my apology URL
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.128}
# USER_NAME USER_NAME She still stans Dricki but she knows it’s never gonna happen
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# “The universe was like just kidding bitch, you’re getting pregnant” #overheardla
# {'neg': 0.242, 'neu': 0.51, 'pos': 0.248, 'compound': -0.2263}
# Getting hungry :upside-down_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Real Dog URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# For full version head to my Youtube channel:
#
# URL
#
# Well what can I say?… URL
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
# :eyes: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Wink wink :winking_face: @ The Strand House URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME She had Hoffs-level eye game.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Hella Big faxxxxxx
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sameee I have watched this show so much and we can only rewatch it till we get our season 2 with our favorite cast! I love them all!!:two_hearts::two_hearts: we can do this guys!  USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME #RenewOnMyBlock URL
# {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.8544}
# :umbrella_with_rain_drops::high_voltage::umbrella_with_rain_drops: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Beautiful day out here in forsan America
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.5994}
# I rebuke that!!!!!!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Friday night baby :grinning_face_with_smiling_eyes::grinning_face_with_smiling_eyes::grinning_face_with_smiling_eyes::grinning_face_with_smiling_eyes::grinning_face_with_smiling_eyes:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Hold on l females put makeup on they bodies too? Why? Just askin URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Marco Rubio's Lonely Fight for the Center - USER_NAME on USER_NAME’s difficult yet needed tightrope walk. URL
# {'neg': 0.369, 'neu': 0.631, 'pos': 0.0, 'compound': -0.765}
# USER_NAME OMG YES
# {'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.4019}
# I did not expect to see death by osmosis tonight... #hypotonicsolution  #2018mmm
# {'neg': 0.281, 'neu': 0.719, 'pos': 0.0, 'compound': -0.5994}
# Its all fun and games till they ask me how old I am :skull:
# {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5106}
# Vikings fans need a new chant because It’s an all purpose Philly chant now. URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Give me till May. I got to walk this stage then I’m lit my G
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #maddow   yeah, USER_NAME doesn't investigate real crimes. Good Riddance Arsehole!
# {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.6588}
# USER_NAME vice versaa:yellow_heart:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The Monster Among Men has graced us with his presence!! USER_NAME #Raw
# {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.3578}
# :heart_with_ribbon: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# We put the fun in fundraiser:woman_dancing::light_skin_tone::woman_dancing::light_skin_tone: @ Quidnessett CountryClub URL
# {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.5106}
# Chicago's Twin Peaks with The Districts and The Nude Party at 123 Pleasant Street Wednesday, April 4th 8PM.
# $12adv/$$15dos 18&up
# URL
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# USER_NAME
# #Morgantown #TwinPeaks #TheDistricts #TheNudeParty URL
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.7184}
# Hasta lo que no te tragas te hace mal
# {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
# :folded_hands::medium-dark_skin_tone::folded_hands::medium-dark_skin_tone::folded_hands::medium-dark_skin_tone:Prayers for the family and team URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #AllTheFeet URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Chase dreams, not people.
# {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# The things to follow... URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Time to GET THESE HANDS!!! USER_NAME #RAW #GetTheseHands
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sixers are gonna have 50+ wins
# {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.5719}
# Overly Attached Bestfriend :face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Do you ever think about stalking me cause i do in case you were wondering ..
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Who’s gonna pay for all the free stuff??  Oh, yeah, the 1%M!  When did it become a bad thing to aspire to be successful?  The American dream doesn’t live in Kamala Harris’s world!  #donothingdems #RedWaveRising
# {'neg': 0.106, 'neu': 0.626, 'pos': 0.268, 'compound': 0.8188}
# USER_NAME Buenas Noches, se puede asistir al juego de la Rayaditas sin ser abonado?
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.5574}
# LMAO glad I could clear that up for you, man URL
# {'neg': 0.0, 'neu': 0.406, 'pos': 0.594, 'compound': 0.8816}
# Signature Banquet is HIRING event team members!  What does the event team consist of you… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Anything fun happening in Tallahassee this week?
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.5106}
# Happy bday pretty gal!!! (*: USER_NAME
# {'neg': 0.0, 'neu': 0.34, 'pos': 0.66, 'compound': 0.8306}
# USER_NAME Lovely picture!
# {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6239}
# USER_NAME You just be too cute sometimes
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.4588}
# USER_NAME Give the kid a break - he has been attacked since going public. He didn’t see who he was responding to and he has apologized. Keep going Kyle. We don’t live in a zero tolerance society. You made a mistake, made amends, and now just keep going.
# {'neg': 0.108, 'neu': 0.802, 'pos': 0.09, 'compound': -0.2263}
# USER_NAME Start a business
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME I hate people too!:face_with_tears_of_joy:
# {'neg': 0.571, 'neu': 0.429, 'pos': 0.0, 'compound': -0.6114}
# USER_NAME first seed got them in the second round, them vrs. raptors lowkey a pick em series
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# After eating biscuits and cupcakes in the same night we gone need it.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# don’t you fucking dare satan.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 8th Grade Boys Baseball rocks the Grizzlies 12-8! Hurricanes are on the move!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Universidades:Cotos de los traficantes de drogas ahí actúan bajo protección de las autoridades,las mismas amparándose en la estupidez,de que autonomía es igual a impunidad,en la UNAM les tienen donado,un centro de distribución,el auditorio Justo Sierra desde hace un buen tiempo.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# of course stevie is friends with safari
# {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.4767}
# Mr Tip over USER_NAME himself Braun strowman is on raw
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# IF I HAD A BODY LIKE THIS ... oh LORD . URL
# {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'compound': 0.4995}
# March 27, 2018 – National Joe Day – National Spanish Paella Day – National American Diabetes Association – National Education and Sharing Day
# {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.4215}
# USER_NAME USER_NAME He got that news flash a tad late. That & he’s kinda slow.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Lmaoo not mee:)))) URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# there’s really only 2 people in the universe i will forever and always be absolutely disgusted by. disgusted isn’t even enough of a word tbh
# {'neg': 0.27, 'neu': 0.73, 'pos': 0.0, 'compound': -0.8119}
# CATFIGHT CATFIGHT
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# How Would You Feel (Paean) by Ed Sheeran
#
# I have never been in love but, he makes me feel as if I had been.
# {'neg': 0.094, 'neu': 0.906, 'pos': 0.0, 'compound': -0.2924}
# So in addition to this being a great bar, bae is bartender and on Monday nights usually requests radio artist prompts from me, so I am essentially guaranteed to enjoy the soundtrack on a Monday.
# {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.8074}
# JUNIEEEEEEEE!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Now mr president you are acting like a president.  You are making a policy decision and staying away from all the sideshows. Just be a president.
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3612}
# Lmfaooo that would be my dad URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Y’all i really would delete Facebook except I wanna keep track of the ppl who are getting married at 20 so I can feel kinda ok about my life.
# {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.228}
# Todos diciendo que a USER_NAME no le queda el color de pelo, pero lo que no saben es que eso fue hace muchoooo, y ahora mismo tiene el pelo del mismo color de siempre... #SoloEsPromoDelVideo #ChaoPescao ¡Sólo 4 días!...
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.5707}
# USER_NAME A verrrrr ...
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Welcome back D. Wish we could all be there....! Good luck and well wishes from ur King Mustang bros. URL
# {'neg': 0.0, 'neu': 0.473, 'pos': 0.527, 'compound': 0.9273}
# You still tweeting me and don’t follow me. Either hit the follow button or keep it pushing URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME Blockchain.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Thank you for helping us. You are a real American hero! URL
# {'neg': 0.0, 'neu': 0.482, 'pos': 0.518, 'compound': 0.8221}
# USER_NAME Yes, having a staff that likes each other and can take a joke is invaluable.  A coaches office where nothing is sacred is a great place.  #hogfbchat
# {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.8957}
# Rep King what’s your heritage jack on your fathers side and ass on your mothers URL
# {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.5423}
# Business trip ? Lmao :face_with_tears_of_joy: URL
# {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.5994}
# USER_NAME, USER_NAME and USER_NAME has teamed up on this National Annual Event - all across the nation! Celebrate and support our veterans with us in our Nations Capital by registering at URL with team code Post12AMVETSDC.  #Post12AMVETSDC #AMVETS URL
# {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.7712}
# They bout to post on Facebook talking about “gettin money” :face_with_rolling_eyes: I already know it . Meanwhile y’all put $5 in the tank. Definition of BOY BYE :sleeping_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Each painting you post just gets better and better. I think this may be my favorite.
# {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.8316}
# I could live off BP pizza except on Tuesday. That one is weak as hell :face_with_tears_of_joy: Monday, Wednesday, and Friday are the best days of the week!
# {'neg': 0.223, 'neu': 0.657, 'pos': 0.12, 'compound': -0.5562}
# USER_NAME USER_NAME USER_NAME Go for it Democrats!
# ...
# {'neg': 0.146, 'neu': 0.574, 'pos': 0.28, 'compound': 0.3729}
# In need of a sugar daddy to buy me some bananas
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Goin' skirt off in that fast car like nascar :smiling_face_with_sunglasses:
# {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
# Yes! Congrats all!!! URL
# {'neg': 0.0, 'neu': 0.216, 'pos': 0.784, 'compound': 0.8057}
# You ain’t even really got to be my boyfriend
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Nah URL
# {'neg': 0.583, 'neu': 0.417, 'pos': 0.0, 'compound': -0.1027}
# lmfaoooo y’all wildin
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I want Chipotle but don’t feel like driving. I need lil yea or a part time bae :loudly_crying_face:
# {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.5267}
# Trey Burke is balling again and Michigan is in The Final 4. Pretty good week for USER_NAME URL
# {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.7269}
# 10 seconds into this song and It's already going to be my new jam #MONSTAX #DEJAVU URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This is *definitely* retouched URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Okay good thing I made this tea with crystals, a little white bruja magic to help ma soul :smiling_face_with_horns:
# {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'compound': 0.7579}
# i feel like crap :weary_face:
# {'neg': 0.366, 'neu': 0.282, 'pos': 0.352, 'compound': -0.0258}
# USER_NAME Crying hot? :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:
# {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# GUYS USER_NAME FOLLOWED ME IM DYING URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :face_with_rolling_eyes::face_with_rolling_eyes::face_with_rolling_eyes: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I need a hug and a bottle to the face
# {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.4767}
# He’s backkkkk:OK_hand::medium-dark_skin_tone::OK_hand::medium-dark_skin_tone: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME #2018MMM URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME lil pump dan schneider icarly
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Starvinggggg
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Mr. Trump? Since it seems you cant find a professional lawyer to work for you and you only have 2 on your team right now, I am giving you the website to the public defender's office. Please feel free to use it at any time.  URL
# {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'compound': 0.7906}
# Sasha resorting to physical violence after being bested in a verbal debate. Sad! #Raw
# {'neg': 0.405, 'neu': 0.595, 'pos': 0.0, 'compound': -0.8172}
# USER_NAME Where can I buy organic Oreos?!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME This is just the start of 2nd year. Imagine this on-going! No successful business could remain functional under this degree of INCOMPETENCE! Normal for Trump is ABNORMAL IN REALITY!
# {'neg': 0.188, 'neu': 0.712, 'pos': 0.1, 'compound': -0.5121}
# Thank you for the gear and for setting up the USER_NAME performance tonight. They were amazing!! I am touched by and appreciative of your support for me, and more importantly, our students and staff! URL
# {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.9439}
# At this rate there’s a good chance Samantha isn’t getting her dog back :smiling_face_with_heart-eyes::face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 0.692, 'pos': 0.308, 'compound': 0.5994}
# USER_NAME let me know what your server code is
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME it’s youuuu:smiling_face_with_heart-eyes:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Thank you for repping the 619 USER_NAME  #Respect  #RootsOfWrestling URL
# {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
# USER_NAME Only way I’m happy is when you are out of the White House!
# {'neg': 0.0, 'neu': 0.765, 'pos': 0.235, 'compound': 0.6114}
# Shades for the shady. URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Why can't Sasha and Sad Bayley make out already?
# {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.3724}
# USER_NAME USER_NAME #forgiveandlive
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# My mom just told me my butt got bigger :relieved_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# they fooled me :face_with_tears_of_joy::face_with_tears_of_joy: URL
# {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.3818}
# URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Gbye
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Drake doing charity?
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# Hahahah I’ve followed an Austin Powers impersonator in insta for four years
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Ansyen miss la finn manbo mezanmi :weary_face::weary_face::weary_face::weary_face:
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.1531}
# USER_NAME Iron Man 3 saw this tweet and LOL’d
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# How does freakin Stevie find a big ass anywhere he goes... dude spend time w/ ur damn daughter  #LeaveItToStevie
# {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.7351}
# Hey friends I’m looking for a full time job in Wichita anyone know of anything???
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.5632}
# if you prefer the apple on the right we can't be friends sorry i don't make the rules URL
# {'neg': 0.129, 'neu': 0.809, 'pos': 0.062, 'compound': -0.3252}
# USER_NAME USER_NAME Congratulations :balloon: USER_NAME winner of two exclusive awards 1.IRAWMA INTERNATIONAL REGEA AWARDS 2.Nickelodeon Award URL
# {'neg': 0.0, 'neu': 0.361, 'pos': 0.639, 'compound': 0.9609}
# Ballerina - Belly #np
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME I think I want that smoke
# {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.0772}
# Mood. USER_NAME :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:
#
# USER_NAME you’ve got a REAL one here!!!!!! #TeyanaAndIman URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Riding around :automobile: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The 49ers are making good progress and improvements but the rams look to be a potential Super Bowl contender next year.  Go Jared go URL
# {'neg': 0.0, 'neu': 0.601, 'pos': 0.399, 'compound': 0.891}
# If it’s cool with you guys imma keep pretending like I know what blockchain is. #WokeAF
# {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.6369}
# whos idkklolz
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Iigh man i'm not boutta watch a TV show about Stevie J
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# “To play any game, you have to start. To win, you have to keep going.”
# {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.7351}
# Get up then!  :eyes: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Lmfaoooooo well give me my one way ticket URL
# {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.2732}
# Cheeseburger broccoli mash and salad
# #paleo #almostAIP #munstercheese #broccoli #salad… URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# some things never change over the years URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Hi, Joe! Thanks for the follow! Excited to connect and learn together!!
# {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compound': 0.7556}
# yeah tommy is the best, right?!! URL
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.7896}
# Caption this URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME Rape is real.
# {'neg': 0.485, 'neu': 0.515, 'pos': 0.0, 'compound': -0.6908}
# USER_NAME He fucking sucks
# {'neg': 0.482, 'neu': 0.518, 'pos': 0.0, 'compound': -0.4201}
# USER_NAME :raising_hands::medium-dark_skin_tone:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# El mejor negocio del mundo es tener una agencia de viajes en un país socialista. URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME @ me next time
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# #Zion :grimacing_face::hundred_points::fire:#McDonaldsAllAmerican URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME Sometime I will! But 3/31 I will be at USER_NAME in #Missoula!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bigger crisis USER_NAME and USER_NAME
# {'neg': 0.506, 'neu': 0.494, 'pos': 0.0, 'compound': -0.6249}
# all this time i wasted & it could’ve been for someone who was actually down for me. smh
# {'neg': 0.282, 'neu': 0.718, 'pos': 0.0, 'compound': -0.6705}
# USER_NAME August???? You’ll be able to write 5 more books about this shitshow between now and at August!!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME can we go to a Styles concert pls
# {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.0772}
# Let's go #Dodgers :white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star::white_medium_star:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME I did
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME JAJA JAJA
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# If somebody hit Beyoncé Ima slap a bitch
# {'neg': 0.365, 'neu': 0.481, 'pos': 0.154, 'compound': -0.4939}
# USER_NAME Just throwing this out....but some types of seriously disturbed persons lie a lot and can never remember what they have told whom, especially when telling same story in different settings/to different audience.
# {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.5106}
# wow you're fake no wonder they left
# {'neg': 0.405, 'neu': 0.305, 'pos': 0.29, 'compound': -0.128}
# my niece starts to scream when you scream one of her nursery rhyme songs & it’s the funniest thing ever :loudly_crying_face::loudly_crying_face:
# {'neg': 0.208, 'neu': 0.654, 'pos': 0.138, 'compound': -0.2023}
# i literally don’t expect too much of nothing from ppl
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME El Q se va a ir eres tu, al molo ya te espera
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# it would be so fye :fire: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I like cuddling and slapping your booty every time u walk by me
# {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# Came home bout 7:40 . Checked fridge . Had a 20 Heineken. Went to Baja . Come home hour and a half later and beer is gone . Ask son what happened to my last beer? He says “ I don’t like getting blamed when something is missing” . Well ... Everyone get the fuck out of my house !
# {'neg': 0.12, 'neu': 0.8, 'pos': 0.08, 'compound': -0.5093}
# Sixers are hitting their damn stride right now and adding USER_NAME back #HereTheyCome
# {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.4019}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME omfg
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME Good looking brodie , much appreciated :raised_fist::medium_skin_tone::hundred_points:
# {'neg': 0.0, 'neu': 0.446, 'pos': 0.554, 'compound': 0.7351}
# USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME USER_NAME #ChavistasQueHuyen  Alicia Monrroy ExFiscal 36 q imputo ala jueza Afiuni vive en Pembroke Pines Fl. Es notario, oficina en Tamarac Fl. Esposo Alejandro Osorio transportista URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME USER_NAME USER_NAME Kinda scary though. Didn’t they build the dam in LA and Katrina busted it
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.4417}
# Proud of you bae :face_blowing_a_kiss: URL
# {'neg': 0.0, 'neu': 0.617, 'pos': 0.383, 'compound': 0.4767}
# So annoyed
# {'neg': 0.743, 'neu': 0.257, 'pos': 0.0, 'compound': -0.4391}
# Welcome to Minnesota USER_NAME!
#
# Come see us when the season is over..... hopefully after a LONG postseason!
#
# #mnwild #EagleValley:eagle: URL
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.7418}
# Kirk telling his kids that he has another child by another woman in front of his wife had to be hard. Alll his fault though.
# {'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.4767}
# :raising_hands::medium_skin_tone::hundred_points: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Quickley teaming up with Wenyen and Quade who both became consistent shooters plus Jemarl Baker...shooting won’t be a problem for the Cats next year. URL
# {'neg': 0.105, 'neu': 0.895, 'pos': 0.0, 'compound': -0.4019}
# We was never oil nigga you was just aighhtt
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME USER_NAME WPS. You will get it too:winking_face:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This dude Danny LoPriore was the funniest dude on Vine; glad to see he got on to Twitter! :face_with_tears_of_joy:
# {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'compound': 0.784}
# Don’t ever lie to me again URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# InBloom :cherry_blossom: USER_NAME URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Post credit: redditor digitalteacup URL
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.3818}
# USER_NAME did you see that throw to first that Sam Freeman made
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
# The extent of conversations with my sister Me: *introduces something exciting or funny*, USER_NAME : “okay bye.”
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.4939}
# :flexed_biceps::medium-light_skin_tone::flexed_biceps::medium-light_skin_tone::flexed_biceps::medium-light_skin_tone: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# USER_NAME WHAT meaningful changes?  The NRA will not allow him to do anything meaningful.
# {'neg': 0.096, 'neu': 0.637, 'pos': 0.266, 'compound': 0.4468}
# USER_NAME Played him in high school! Great player
# {'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.7777}
# USER_NAME Wyd
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Trey gashed his leg on the stage and will be playing electric guitar with a blood stain on his… URL
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2023}
# shottas vs paid in full URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This guy sounds like a great fit for the Kansas City Royals front office! URL
# {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.8553}
# USER_NAME Hurry up :face_with_stuck-out_tongue:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It's crazy how my squat form was shit back then, 315 would send me straight to the ground as soon as I lifted off the rack.. and now I'm chasing 400's on squats
# {'neg': 0.163, 'neu': 0.786, 'pos': 0.051, 'compound': -0.6249}
# PLEASE URL
# {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
# High school students are marching 50 miles to Paul Ryan’s home town to call him out on guns URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Why do I love this so much URL
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# USER_NAME USER_NAME bat bawal pag si paps?
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# :fire::fire::fire::fire::fire::fire::fire::fire::fire: URL
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It should be required that these “Authentic Fans” have their Chinese jerseys thrown in the garbage and gifted real ones.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# tweets = ["if you prefer the apple on the right we can't be friends sorry i don't make the rules URL",
#           "How does freakin Stevie find a big ass anywhere he goes... dude spend time w/ ur damn daughter  #LeaveItToStevie",
#           "Some people act like addiction just became a thing w/the opioid crisis, saying things like: Now addiction affects everybody. Addiction doesn't discriminate anymore. Um, that shit didn't just start happening & the only thing that EVER discriminated was us & our drug policies.",
#           "Yes! Congrats all!!! URL"]
