# %%
import pandas as pd
import numpy as np
import csv
from datetime import datetime
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# True

# %%
vader_analyzer = SentimentIntensityAnalyzer()

# %%
counter = 0

# %%
with open(r'./twitter_scraper/data/twitter_data.csv', encoding='cp1257') as f:
    reader = csv.reader(f)
    for row in reader:
        [date_str, text, user_id, location] = row
        dt = datetime.strptime(date_str, "%a %b %d %H:%M:%S %z %Y")
        print(row)
        print(vader_analyzer.polarity_scores(text))
        counter += 1
# Out:
# ['Tue Mar 27 01:32:57 +0000 2018', 'After today I am not spending a single fucking dime. Yeah I’ll starve, and yeah I’ll miss my chances on getting shit I want, but enough is enough Jasmine. :sleepy_face:', '874469849992278016', 'Los Angeles, CA']
# {'neg': 0.177, 'neu': 0.636, 'pos': 0.187, 'compound': -0.1682}
# ['Tue Mar 27 01:32:57 +0000 2018', 'Trust the process', '388441336', 'White Marsh, MD']
# {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'compound': 0.5106}
# ['Tue Mar 27 01:32:57 +0000 2018', "USER_NAME Seton Hall, St. John, Syracuse and UConn didn't make it.", '949745290973675520', 'Lower East Side, Manhattan']
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ['Tue Mar 27 01:32:57 +0000 2018', '*21 but facts URL', '762917798414655488', 'Huntsville, TX']
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ['Tue Mar 27 01:32:57 +0000 2018', 'USER_NAME USER_NAME USER_NAME :eyes::thinking_face:', '1191760663', 'Florida, USA']
# ...

# %%
counter
# Out:
# 977

# %%
# tweets = ["if you prefer the apple on the right we can't be friends sorry i don't make the rules URL",
#           "How does freakin Stevie find a big ass anywhere he goes... dude spend time w/ ur damn daughter  #LeaveItToStevie",
#           "Some people act like addiction just became a thing w/the opioid crisis, saying things like: Now addiction affects everybody. Addiction doesn't discriminate anymore. Um, that shit didn't just start happening & the only thing that EVER discriminated was us & our drug policies.",
#           "Yes! Congrats all!!! URL"]
